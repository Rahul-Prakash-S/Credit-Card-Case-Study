# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
# %matplotlib inline
import seaborn as sns
import os
import datetime as dt

# %%
cust=pd.read_csv("C:\\Users\\USER\\Projects\\EDA\\data\\Case study-2//Customer Acqusition.csv")
repay=pd.read_csv("C:\\Users\\USER\\Projects\\EDA\\data\\Case study-2//Repayment.csv")
spend=pd.read_csv("C:\\Users\\USER\\Projects\\EDA\\data\\Case study-2//spend.csv")

# %%
cust.head()
# Out:
#    No Customer  Age       City   Product     Limit Company        Segment
# 0   1       A1   76  BANGALORE      Gold  500000.0      C1  Self Employed
# 1   2       A2   71   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2   3       A3   34     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3   4       A4   47     BOMBAY  Platimum   10001.0      C4           Govt
# 4   5       A5   56  BANGALORE  Platimum   10002.0      C5  Normal Salary

# %%
cust.dtypes
# Out:
# No            int64
# Customer     object
# Age           int64
# City         object
# Product      object
# Limit       float64
# Company      object
# Segment      object
# dtype: object

# %%
cust.isnull().sum()
# Out:
# No          0
# Customer    0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# dtype: int64

# %%
repay.head()
# Out:
#    SL No: Customer      Month     Amount  Unnamed: 4
# 0     NaN       A1  12-Jan-04  495414.75         NaN
# 1     2.0       A1   3-Jan-04  245899.02         NaN
# 2     3.0       A1  15-Jan-04  259490.06         NaN
# 3     4.0       A1  25-Jan-04  437555.12         NaN
# 4     5.0       A1  17-Jan-05  165972.88         NaN

# %%
repay.dtypes
# Out:
# SL No:        float64
# Customer       object
# Month          object
# Amount        float64
# Unnamed: 4    float64
# dtype: object

# %%
repay.isnull().sum()
# Out:
# SL No:          24
# Customer        23
# Month           23
# Amount          23
# Unnamed: 4    1523
# dtype: int64

# %%
repay.dropna(axis=1,how='all',inplace=True)

# %%
repay.dropna(axis=0,how='all',inplace=True)

# %%
repay.isnull().sum()
# Out:
# SL No:      1
# Customer    0
# Month       0
# Amount      0
# dtype: int64

# %%
repay.head()
# Out:
#    SL No: Customer      Month     Amount
# 0     NaN       A1  12-Jan-04  495414.75
# 1     2.0       A1   3-Jan-04  245899.02
# 2     3.0       A1  15-Jan-04  259490.06
# 3     4.0       A1  25-Jan-04  437555.12
# 4     5.0       A1  17-Jan-05  165972.88

# %%
spend.head()
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13
# 2       3       A1  15-Jan-04    CLOTHES   23740.46
# 3       4       A1  25-Jan-04       FOOD  484342.47
# 4       5       A1  17-Jan-05     CAMERA  369694.07

# %%
spend.dtypes
# Out:
# Sl No:        int64
# Customer     object
# Month        object
# Type         object
# Amount      float64
# dtype: object

# %%
spend.isnull().sum()
# Out:
# Sl No:      0
# Customer    0
# Month       0
# Type        0
# Amount      0
# dtype: int64

# %% [markdown]
# # (1) In the above dataset,¶
# (a) In case age is less than 18, replace it with mean of age values

# %%
mean_age=cust['Age'].mean()

# %%
mean_age
# Out:
# 46.49

# %%
cust.loc[cust["Age"]<18,"Age"]=cust["Age"].mean()

# %%
meannew = cust["Age"].mean()

# %%
meannew
# Out:
# 48.399399999999986

# %%
print("The new age is",meannew)
# Out:
# The new age is 48.399399999999986

# %% [markdown]
# # b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit.
# (customer’s limit provided in acquisition table is the per transaction limit on his card)

# %%
spend.head()
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13
# 2       3       A1  15-Jan-04    CLOTHES   23740.46
# 3       4       A1  25-Jan-04       FOOD  484342.47
# 4       5       A1  17-Jan-05     CAMERA  369694.07

# %%
cust.head()
# Out:
#    No Customer   Age       City   Product     Limit Company        Segment
# 0   1       A1  76.0  BANGALORE      Gold  500000.0      C1  Self Employed
# 1   2       A2  71.0   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2   3       A3  34.0     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3   4       A4  47.0     BOMBAY  Platimum   10001.0      C4           Govt
# 4   5       A5  56.0  BANGALORE  Platimum   10002.0      C5  Normal Salary

# %%
cust_spend=pd.merge(left=cust,right=spend,on="Customer",how="inner")

# %%
cust_spend
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount
# 0     Self Employed       1  12-Jan-04   JEWELLERY  485470.80
# ...

# %%
cust_spend[cust_spend["Amount"]>cust_spend["Limit"]]
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 18      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 19      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 20      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 21      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# 22      2       A2  71.0    CALCUTTA    Silver  100000.0      C2
# ...   ...      ...   ...         ...       ...       ...     ...
# 1486   87      A87  27.0    CALCUTTA    Silver  100003.0     C10
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month          Type     Amount
# 18     Salaried_MNC     104   3-Jan-04        RENTAL  199554.72
# ...

# %%
cust_spend.loc[cust_spend["Amount"]>cust_spend["Limit"],"Amount"]=(50*cust_spend["Limit"]).div(100)

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount
# 0       1  12-Jan-04  JEWELLERY  485470.80
# 1       2   3-Jan-04      PETRO  410556.13
# 2       3  15-Jan-04    CLOTHES   23740.46
# 3       4  25-Jan-04       FOOD  484342.47
# 4       5  17-Jan-05     CAMERA  369694.07

# %% [markdown]
# # c. Incase the repayment amount is more than the limit, replace the repayment with the limit.

# %%
repay.head()
# Out:
#    SL No: Customer      Month     Amount
# 0     NaN       A1  12-Jan-04  495414.75
# 1     2.0       A1   3-Jan-04  245899.02
# 2     3.0       A1  15-Jan-04  259490.06
# 3     4.0       A1  25-Jan-04  437555.12
# 4     5.0       A1  17-Jan-05  165972.88

# %%
cust_repay=pd.merge(left=repay,right=cust,on="Customer",how="inner")

# %%
cust_repay[cust_repay["Amount"]>cust_repay["Limit"]]
# Out:
#       SL No: Customer      Month     Amount  No   Age    City Product  \
# 18       8.0       A8   5-Feb-04  156913.59   8  67.0   PATNA  Silver
# 19     110.0       A8  12-Jan-04  350999.98   8  67.0   PATNA  Silver
# 20     124.0       A8  31-Mar-06  155642.95   8  67.0   PATNA  Silver
# 21     138.0       A8   9-May-05  145457.38   8  67.0   PATNA  Silver
# 22     152.0       A8   8-May-06  361184.89   8  67.0   PATNA  Silver
# ...      ...      ...        ...        ...  ..   ...     ...     ...
# 1494   259.0       A7   6-May-06  400375.97   7  26.0  COCHIN  Silver
# 1496   295.0       A7   3-Dec-05  429700.12   7  26.0  COCHIN  Silver
# 1497   313.0       A7  23-Feb-05  344628.72   7  26.0  COCHIN  Silver
# 1498   331.0       A7  31-Mar-06  336264.37   7  26.0  COCHIN  Silver
# 1499   349.0       A7   3-Jan-04  473662.61   7  26.0  COCHIN  Silver
#
#          Limit Company       Segment
# 18    100002.0      C8  Salaried_Pvt
# 19    100002.0      C8  Salaried_Pvt
# ...

# %%
cust_repay.loc[cust_repay["Amount"]>cust_repay["Limit"],"Limit"]=cust_repay["Limit"]

# %%
cust_repay
# Out:
#       SL No: Customer      Month     Amount  No   Age       City Product  \
# 0        NaN       A1  12-Jan-04  495414.75   1  76.0  BANGALORE    Gold
# 1        2.0       A1   3-Jan-04  245899.02   1  76.0  BANGALORE    Gold
# 2        3.0       A1  15-Jan-04  259490.06   1  76.0  BANGALORE    Gold
# 3        4.0       A1  25-Jan-04  437555.12   1  76.0  BANGALORE    Gold
# 4        5.0       A1  17-Jan-05  165972.88   1  76.0  BANGALORE    Gold
# ...      ...      ...        ...        ...  ..   ...        ...     ...
# 1495   277.0       A7  22-Nov-05   55108.71   7  26.0     COCHIN  Silver
# 1496   295.0       A7   3-Dec-05  429700.12   7  26.0     COCHIN  Silver
# 1497   313.0       A7  23-Feb-05  344628.72   7  26.0     COCHIN  Silver
# 1498   331.0       A7  31-Mar-06  336264.37   7  26.0     COCHIN  Silver
# 1499   349.0       A7   3-Jan-04  473662.61   7  26.0     COCHIN  Silver
#
#          Limit Company        Segment
# 0     500000.0      C1  Self Employed
# ...

# %% [markdown]
# # 2) From the above dataset create the following summaries:
# a)How many distinct customers exist?

# %%
dist_cust=cust["Customer"].nunique()

# %%
dist_cust
# Out:
# 100

# %% [markdown]
# b. How many distinct categories exist?

# %%
dist_cat=cust["Segment"].nunique()

# %%
dist_cat
# Out:
# 5

# %%
plot.figure(figsize=(6,6))
sns.countplot("Segment",data=cust)
plot.show()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# c. What is the average monthly spend by customers?

# %%
spend.head()
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13
# 2       3       A1  15-Jan-04    CLOTHES   23740.46
# 3       4       A1  25-Jan-04       FOOD  484342.47
# 4       5       A1  17-Jan-05     CAMERA  369694.07

# %%
spend["Month"]=pd.to_datetime(spend["Month"])

# %%
spend["Month"].dtypes
# Out:
# dtype('<M8[ns]')

# %%
spend['month'] = spend["Month"].apply(lambda x: dt.datetime.strftime(x,"%B"))

# %%
spend['year'] = spend['Month'].apply(lambda x: dt.datetime.strftime(x,'%Y'))

# %%
spend
# Out:
#       Sl No: Customer      Month        Type     Amount     month  year
# 0          1       A1 2004-01-12   JEWELLERY  485470.80   January  2004
# 1          2       A1 2004-01-03       PETRO  410556.13   January  2004
# 2          3       A1 2004-01-15     CLOTHES   23740.46   January  2004
# 3          4       A1 2004-01-25        FOOD  484342.47   January  2004
# 4          5       A1 2005-01-17      CAMERA  369694.07   January  2005
# ...      ...      ...        ...         ...        ...       ...   ...
# 1495    1496      A67 2006-02-04  BUS TICKET  356872.73  February  2006
# 1496    1497      A68 2006-03-25  BUS TICKET  204971.10     March  2006
# 1497    1498      A69 2006-03-31  BUS TICKET   50449.44     March  2006
# 1498    1499      A70 2006-03-23  BUS TICKET   80593.94     March  2006
# 1499    1500      A71 2006-03-24  BUS TICKET  194447.62     March  2006
#
# [1500 rows x 7 columns]

# %%
spend_new=round(spend.groupby(['year','month']).mean(),2)

# %%
spend_new
# Out:
#                 Sl No:     Amount
# year month
# 2004 April      730.50  235272.04
#      February   749.50  221215.27
#      January    751.62  251712.07
#      March      725.50  232146.12
#      May        733.50  217539.24
#      November   745.50  270486.40
#      September  741.50  310923.38
# 2005 April      730.00  252181.33
#      August     749.50  233734.63
#      December   762.50  147503.06
#      February   750.67  229802.28
#      January    746.50  292741.37
#      July       757.50  229116.66
#      June       755.50  262688.11
#      May        747.30  245696.52
#      November   749.50  286143.32
#      October    760.50  194568.64
#      September  759.50  188666.20
# 2006 April      744.41  232468.97
#      August     770.50  240699.72
#      December   774.50  270470.98
#      February   757.83  253858.26
#      January    763.50  282058.01
#      July       754.50  287505.10
#      June       768.50  177252.39
#      March      750.90  247166.08
# ...

# %% [markdown]
# d)What is the average monthly repayment by customers?

# %%
repay.head()
# Out:
#    SL No: Customer      Month     Amount
# 0     NaN       A1  12-Jan-04  495414.75
# 1     2.0       A1   3-Jan-04  245899.02
# 2     3.0       A1  15-Jan-04  259490.06
# 3     4.0       A1  25-Jan-04  437555.12
# 4     5.0       A1  17-Jan-05  165972.88

# %%
repay.dtypes
# Out:
# SL No:      float64
# Customer     object
# Month        object
# Amount      float64
# dtype: object

# %%
repay["Month"]=pd.to_datetime(repay["Month"])

# %%
repay["Month"].dtypes
# Out:
# dtype('<M8[ns]')

# %%
repay["month"]=repay["Month"].apply(lambda x:pd.Timestamp.strftime(x,"%B"))
repay["year"]=repay["Month"].apply(lambda x:pd.Timestamp.strftime(x,"%Y"))

# %%
repay
# Out:
#       SL No: Customer      Month     Amount      month  year
# 0        NaN       A1 2004-01-12  495414.75    January  2004
# 1        2.0       A1 2004-01-03  245899.02    January  2004
# 2        3.0       A1 2004-01-15  259490.06    January  2004
# 3        4.0       A1 2004-01-25  437555.12    January  2004
# 4        5.0       A1 2005-01-17  165972.88    January  2005
# ...      ...      ...        ...        ...        ...   ...
# 1495  1496.0      A67 2005-05-09   55638.77        May  2005
# 1496  1497.0      A68 2006-05-10  319836.49        May  2006
# 1497  1498.0      A69 2006-07-11  247628.45       July  2006
# 1498  1499.0      A70 2005-08-12  454016.51     August  2005
# 1499  1500.0      A71 2004-09-13   56286.33  September  2004
#
# [1500 rows x 6 columns]

# %%
repay_new=round(repay.groupby(["year","month"]).mean(),2)

# %%
repay_new
# Out:
#                 SL No:     Amount
# year month
# 2004 April      805.07  259141.68
#      February   764.33  256702.63
#      January    746.66  243489.65
#      March      800.07  252585.28
#      May        760.80  226162.72
#      November   744.93  209592.24
#      September  788.38  184487.85
# 2005 April      804.57  212688.63
#      August     748.05  264430.92
#      December   710.92  320379.34
#      February   765.50  238829.27
#      January    761.33  240548.10
#      July       705.92  239871.48
#      June       703.92  210199.82
#      May        738.08  263207.37
#      November   733.50  256695.12
#      October    708.92  219849.96
#      September  707.92  247700.17
# 2006 April      763.03  275472.25
#      August     718.92  224143.99
#      December   722.92  252736.57
#      February   751.97  284489.57
#      January    711.92  293475.39
#      July       750.95  257936.38
#      June       716.92  251990.45
#      March      757.00  240851.27
# ...

# %% [markdown]
# # (e) If the monthly rate of interest is 2.9%, what is the profit for the bank for each month?

# %%
cust_spend_repay=pd.merge(left=cust_spend,right=repay,on="Customer",how="inner")

# %%
cust_spend_repay.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:    Month_x       Type  Amount_x  SL No:    Month_y   Amount_y  \
# 0       1  12-Jan-04  JEWELLERY  485470.8     NaN 2004-01-12  495414.75
# 1       1  12-Jan-04  JEWELLERY  485470.8     2.0 2004-01-03  245899.02
# 2       1  12-Jan-04  JEWELLERY  485470.8     3.0 2004-01-15  259490.06
# 3       1  12-Jan-04  JEWELLERY  485470.8     4.0 2004-01-25  437555.12
# 4       1  12-Jan-04  JEWELLERY  485470.8     5.0 2005-01-17  165972.88
#
#      month  year
# 0  January  2004
# 1  January  2004
# 2  January  2004
# 3  January  2004
# ...

# %%
cust_spend_repay.rename(columns={"Amount_x":"Spndamnt","Amount_y":"Rpayamt"},inplace=True)

# %%
cust_spend_repay.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:    Month_x       Type  Spndamnt  SL No:    Month_y    Rpayamt  \
# 0       1  12-Jan-04  JEWELLERY  485470.8     NaN 2004-01-12  495414.75
# 1       1  12-Jan-04  JEWELLERY  485470.8     2.0 2004-01-03  245899.02
# 2       1  12-Jan-04  JEWELLERY  485470.8     3.0 2004-01-15  259490.06
# 3       1  12-Jan-04  JEWELLERY  485470.8     4.0 2004-01-25  437555.12
# 4       1  12-Jan-04  JEWELLERY  485470.8     5.0 2005-01-17  165972.88
#
#      month  year
# 0  January  2004
# 1  January  2004
# 2  January  2004
# 3  January  2004
# ...

# %%
interest_group=cust_spend_repay.groupby(["year","month"])["Spndamnt","Rpayamt"].sum()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10864\466200659.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   interest_group=cust_spend_repay.groupby(["year","month"])["Spndamnt","Rpayamt"].sum()

# %%
interest_group
# Out:
#                     Spndamnt       Rpayamt
# year month
# 2004 April      1.194516e+08  2.285403e+08
#      February   7.613922e+07  1.602419e+08
#      January    1.088357e+09  1.699210e+09
#      March      5.594171e+07  8.974470e+07
#      May        8.800456e+07  1.411594e+08
#      November   5.504612e+07  7.860290e+07
#      September  5.144278e+07  8.016122e+07
# 2005 April      9.366405e+07  1.747894e+08
#      August     1.361400e+08  2.477449e+08
#      December   4.348638e+07  9.944533e+07
#      February   5.890557e+08  9.416163e+08
#      January    1.324129e+08  1.810333e+08
#      July       3.995653e+07  7.997268e+07
#      June       1.174019e+08  2.213774e+08
#      May        7.149030e+08  1.099197e+09
#      November   1.532278e+08  2.763119e+08
#      October    3.140993e+07  6.027830e+07
#      September  3.195551e+07  7.530449e+07
# 2006 April      3.229722e+08  6.093666e+08
#      August     5.849630e+07  7.167032e+07
# ...

# %%
interest_group["monthlyinterest"]=interest_group["Spndamnt"]-interest_group["Rpayamt"]

# %%
interest_group
# Out:
#                     Spndamnt       Rpayamt  monthlyinterest
# year month
# 2004 April      1.194516e+08  2.285403e+08    -1.090887e+08
#      February   7.613922e+07  1.602419e+08    -8.410268e+07
#      January    1.088357e+09  1.699210e+09    -6.108525e+08
#      March      5.594171e+07  8.974470e+07    -3.380298e+07
#      May        8.800456e+07  1.411594e+08    -5.315485e+07
#      November   5.504612e+07  7.860290e+07    -2.355678e+07
#      September  5.144278e+07  8.016122e+07    -2.871844e+07
# 2005 April      9.366405e+07  1.747894e+08    -8.112539e+07
#      August     1.361400e+08  2.477449e+08    -1.116049e+08
#      December   4.348638e+07  9.944533e+07    -5.595895e+07
#      February   5.890557e+08  9.416163e+08    -3.525606e+08
#      January    1.324129e+08  1.810333e+08    -4.862042e+07
#      July       3.995653e+07  7.997268e+07    -4.001615e+07
#      June       1.174019e+08  2.213774e+08    -1.039755e+08
# ...

# %%
interest_group["Mon_earned"]=(2.9*interest_group["monthlyinterest"])/100

# %%
interest_group
# Out:
#                     Spndamnt       Rpayamt  monthlyinterest    Mon_earned
# year month
# 2004 April      1.194516e+08  2.285403e+08    -1.090887e+08 -3.163572e+06
#      February   7.613922e+07  1.602419e+08    -8.410268e+07 -2.438978e+06
#      January    1.088357e+09  1.699210e+09    -6.108525e+08 -1.771472e+07
#      March      5.594171e+07  8.974470e+07    -3.380298e+07 -9.802865e+05
#      May        8.800456e+07  1.411594e+08    -5.315485e+07 -1.541491e+06
#      November   5.504612e+07  7.860290e+07    -2.355678e+07 -6.831466e+05
#      September  5.144278e+07  8.016122e+07    -2.871844e+07 -8.328349e+05
# 2005 April      9.366405e+07  1.747894e+08    -8.112539e+07 -2.352636e+06
#      August     1.361400e+08  2.477449e+08    -1.116049e+08 -3.236542e+06
#      December   4.348638e+07  9.944533e+07    -5.595895e+07 -1.622810e+06
#      February   5.890557e+08  9.416163e+08    -3.525606e+08 -1.022426e+07
# ...

# %% [markdown]
# f. What are the top 5 product types?

# %%
spend["Type"].value_counts().head()
# Out:
# PETRO           200
# FOOD            160
# CAMERA          160
# AIR TICKET      147
# TRAIN TICKET    132
# Name: Type, dtype: int64

# %%
spend["Type"].value_counts().head(5).plot(kind="bar")
plot.show()

# %% [markdown]
# g. Which city is having maximum spend?

# %%
city_spend=cust_spend.groupby("City")["Amount"].sum()

# %%
city_spend
# Out:
# City
# BANGALORE     40461647.02
# BOMBAY        28603127.38
# CALCUTTA      41108132.30
# CHENNAI       22128635.65
# COCHIN        45963513.50
# DELHI         10918286.54
# PATNA         15260586.97
# TRIVANDRUM    15337155.87
# Name: Amount, dtype: float64

# %%
plot.figure(figsize=(8,6))
city_spend.plot(kind="pie",autopct="%1.0f%%")
plot.show()

# %% [markdown]
# h. Which age group is spending more money?

# %%
cust_spend
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount
# 0     Self Employed       1  12-Jan-04   JEWELLERY  485470.80
# ...

# %%
cust_spend["Age_group"]=pd.cut(cust_spend["Age"],
                               bins=np.arange(18,88,8),
                               labels=["18-26","26-34", "34-42" ,"42-50" ,"50-58","58-66","66-74","74-82"]
                               ,include_lowest=True)

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount Age_group
# 0       1  12-Jan-04  JEWELLERY  485470.80     74-82
# 1       2   3-Jan-04      PETRO  410556.13     74-82
# 2       3  15-Jan-04    CLOTHES   23740.46     74-82
# 3       4  25-Jan-04       FOOD  484342.47     74-82
# 4       5  17-Jan-05     CAMERA  369694.07     74-82

# %%
age_spend=cust_spend.groupby("Age_group")["Amount"].sum()

# %%
age_spend
# Out:
# Age_group
# 18-26    25233896.65
# 26-34    30553459.81
# 34-42    38037826.50
# 42-50    53242390.70
# 50-58    22454066.68
# 58-66    12782683.13
# 66-74    17705877.44
# 74-82    19770884.32
# Name: Amount, dtype: float64

# %%
plot.figure(figsize=(6,8))
age_spend.plot(kind="pie",autopct="%1.0f%%")
plot.show()

# %% [markdown]
# i) Who are the top 10 customers in terms of repayment?

# %%
cust_repay.head()
# Out:
#    SL No: Customer      Month     Amount  No   Age       City Product  \
# 0     NaN       A1  12-Jan-04  495414.75   1  76.0  BANGALORE    Gold
# 1     2.0       A1   3-Jan-04  245899.02   1  76.0  BANGALORE    Gold
# 2     3.0       A1  15-Jan-04  259490.06   1  76.0  BANGALORE    Gold
# 3     4.0       A1  25-Jan-04  437555.12   1  76.0  BANGALORE    Gold
# 4     5.0       A1  17-Jan-05  165972.88   1  76.0  BANGALORE    Gold
#
#       Limit Company        Segment
# 0  500000.0      C1  Self Employed
# 1  500000.0      C1  Self Employed
# 2  500000.0      C1  Self Employed
# 3  500000.0      C1  Self Employed
# 4  500000.0      C1  Self Employed

# %%
cust_repay.groupby("Amount")[["Customer"]].sum().sort_values(by="Amount",ascending=False).head(10)
# Out:
#           Customer
# Amount
# 499930.66      A11
# 498705.93      A40
# 498284.19      A13
# 498258.64      A53
# 498238.63      A36
# 498001.25      A12
# 497928.27      A40
# 497237.97      A89
# 497223.08      A57
# 496791.06      A12

# %% [markdown]
# # 3) Calculate the city wise spend on each product on yearly basis. Also include a graphical representation for the same.

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount Age_group
# 0       1  12-Jan-04  JEWELLERY  485470.80     74-82
# 1       2   3-Jan-04      PETRO  410556.13     74-82
# 2       3  15-Jan-04    CLOTHES   23740.46     74-82
# 3       4  25-Jan-04       FOOD  484342.47     74-82
# 4       5  17-Jan-05     CAMERA  369694.07     74-82

# %%
cust_spend["Month"]=pd.to_datetime(cust_spend["Month"])

# %%
cust_spend["Year"]=cust_spend["Month"].apply(lambda x: pd.Timestamp.strftime(x,format="%Y"))

# %%
cust_spend.head(3)
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount Age_group  Year
# 0       1 2004-01-12  JEWELLERY  485470.80     74-82  2004
# 1       2 2004-01-03      PETRO  410556.13     74-82  2004
# 2       3 2004-01-15    CLOTHES   23740.46     74-82  2004

# %%
cust_spend_pivot=pd.pivot_table(data=cust_spend,index=["City","Year"],columns="Product",aggfunc="sum",values="Amount")

# %%
cust_spend_pivot
# Out:
# Product                 Gold    Platimum      Silver
# City       Year
# BANGALORE  2004   9289878.54  1112732.30  1291852.58
#            2005  12892362.99   912284.97   830612.34
#            2006  12030611.09   685831.27  1415480.94
# BOMBAY     2004   6987853.53   897264.94   532089.03
#            2005   8983018.28   711804.94   508988.54
#            2006   7917144.31   972130.01  1092833.80
# CALCUTTA   2004   7477140.98  2037690.30   500006.00
#            2005  10303355.80  4434696.31   440147.06
#            2006  11167532.77  3589606.66  1157956.42
# CHENNAI    2004   1059618.50  3535652.38   282056.86
#            2005   3740945.58  5053956.32   377184.49
#            2006   2704288.62  5024923.40   350009.50
# COCHIN     2004   7315850.15  3419904.07   814229.62
#            2005  12110613.03  4960921.71   652269.38
#            2006  10499142.38  4920592.29  1269990.87
# DELHI      2004   2806495.00   283512.89   768172.30
# ...

# %%
cust_spend_pivot.plot(kind="bar",figsize=(18,5),width=0.8)
plot.ylabel("Spend Amount")
plot.title("Amount spended by customers according to year and city")
plot.show()

# %% [markdown]
# # 4) Create graphs for
# (a) Monthly comparison of total spends, city wise

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:      Month       Type     Amount Age_group  Year
# 0       1 2004-01-12  JEWELLERY  485470.80     74-82  2004
# 1       2 2004-01-03      PETRO  410556.13     74-82  2004
# 2       3 2004-01-15    CLOTHES   23740.46     74-82  2004
# 3       4 2004-01-25       FOOD  484342.47     74-82  2004
# 4       5 2005-01-17     CAMERA  369694.07     74-82  2005

# %%
cust_spend["Month"]=cust_spend["Month"].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:    Month       Type     Amount Age_group  Year
# 0       1  January  JEWELLERY  485470.80     74-82  2004
# 1       2  January      PETRO  410556.13     74-82  2004
# 2       3  January    CLOTHES   23740.46     74-82  2004
# 3       4  January       FOOD  484342.47     74-82  2004
# 4       5  January     CAMERA  369694.07     74-82  2005

# %%
month_city = cust_spend.groupby(["Month","City"])[["Amount"]].sum().sort_index().reset_index()

# %%
month_city_pivot=pd.pivot_table(data=cust_spend,
                                values="Amount",
                                index="City",
                                columns="Month",
                                aggfunc="sum")

# %%
month_city_pivot
# Out:
# Month            April      August   December    February      January  \
# City
# BANGALORE   4207980.48   695061.95  422167.24  6734494.76   9041796.84
# BOMBAY      1873785.01  1066744.75  140040.71  4276988.30   5948993.33
# CALCUTTA    3457507.95  1548354.02   55001.50  8150545.61   9064864.90
# CHENNAI     2518656.99   305875.97  223628.27  4385815.95   4466961.36
# COCHIN      3882744.94  2317306.61  909533.05  5747886.38  11714373.54
# DELHI        777240.75   155402.16  842342.02  1494064.06   2714261.45
# PATNA       2338179.53   419383.64   50000.00  2353333.55   4916205.55
# TRIVANDRUM  1199293.45   453773.94  640922.26  2857123.89   3704336.99
#
# Month             July        June       March         May    November  \
# City
# BANGALORE   2228217.69  1330685.90  5362903.07  6383115.13  2260603.07
# BOMBAY       177726.32  1172594.97  5227850.50  3891945.60  2872049.40
# CALCUTTA    2234573.27  2293045.81  4939040.04  5578246.87  2078880.93
# ...

# %%
month_city.plot(kind="bar",figsize=(20,10),width=1)
plot.show()

# %% [markdown]
# b. Comparison of yearly spend on air tickets

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:    Month       Type     Amount Age_group  Year
# 0       1  January  JEWELLERY  485470.80     74-82  2004
# 1       2  January      PETRO  410556.13     74-82  2004
# 2       3  January    CLOTHES   23740.46     74-82  2004
# 3       4  January       FOOD  484342.47     74-82  2004
# 4       5  January     CAMERA  369694.07     74-82  2005

# %%
spend_type=cust_spend.groupby(["Year","Type"])[["Amount"]].sum().reset_index()

# %%
spend_type
# Out:
#     Year          Type       Amount
# 0   2004    AIR TICKET   4357225.35
# 1   2004          AUTO    254745.28
# 2   2004          BIKE    476635.28
# 3   2004    BUS TICKET   5822074.21
# 4   2004        CAMERA  10122819.72
# 5   2004           CAR   2326442.62
# 6   2004       CLOTHES   2685429.91
# 7   2004          FOOD   7727298.46
# 8   2004     JEWELLERY   2579785.80
# 9   2004  MOVIE TICKET   1588392.99
# 10  2004         PETRO   6804320.16
# 11  2004        RENTAL   3599302.60
# 12  2004       SANDALS   1035558.89
# 13  2004      SHOPPING   6776103.78
# 14  2004  TRAIN TICKET   2984633.51
# 15  2005    AIR TICKET  10550152.21
# 16  2005          AUTO   1192725.78
# 17  2005          BIKE   4228406.18
# 18  2005    BUS TICKET   7387034.98
# 19  2005        CAMERA   9614498.20
# 20  2005           CAR     74247.30
# 21  2005       CLOTHES   4961423.88
# 22  2005          FOOD   6739275.69
# 23  2005     JEWELLERY   4228154.11
# 24  2005  MOVIE TICKET   4490299.74
# ...

# %%
Air=spend_type.loc[spend_type["Type"]=="AIR TICKET"]

# %%
Air
# Out:
#     Year        Type       Amount
# 0   2004  AIR TICKET   4357225.35
# 15  2005  AIR TICKET  10550152.21
# 30  2006  AIR TICKET   5248469.56

# %%
plot.bar(Air["Year"],height=Air["Amount"])
plot.xlabel("Year")
plot.ylabel("Amnt spent")
plot.title("Air ticket amount spent")
plot.show()

# %% [markdown]
# # c. Comparison of monthly spend for each product (look for any seasonality that exists in terms of spend)

# %%
cust_spend.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    Sl No:    Month       Type     Amount Age_group  Year
# 0       1  January  JEWELLERY  485470.80     74-82  2004
# 1       2  January      PETRO  410556.13     74-82  2004
# 2       3  January    CLOTHES   23740.46     74-82  2004
# 3       4  January       FOOD  484342.47     74-82  2004
# 4       5  January     CAMERA  369694.07     74-82  2005

# %%
prod_spent=pd.pivot_table(data=cust_spend,index="Product",columns="Month",values="Amount",aggfunc=sum)

# %%
prod_spent
# Out:
# Month           April      August    December     February      January  \
# Product
# Gold      13170572.59  4954030.42  2332940.96  24779179.55  32413831.83
# Platimum   5182493.86  1714762.80   750156.19   9134054.58  14951578.51
# Silver     1902322.65   293109.82   200537.90   2087018.37   4206383.62
#
# Month           July        June        March          May    November  \
# Product
# Gold      5167416.37  6538862.64  19256972.48  21548169.76  9203267.46
# Platimum  1288156.26  2965712.71   7288837.68   8151926.49  2741618.42
# Silver     530153.72   689537.61   3909405.83   2140940.01   691102.63
#
# Month        October   September
# Product
# Gold      3018223.38  3816887.62
# Platimum   550275.04  1667840.84
# Silver     100001.50   442803.13

# %%
prod_spent.plot(kind="bar",figsize=(20,10),width=1)
plot.ylabel("Amount spend")
plot.title("Amount spend on diff products")
plot.show()

# %% [markdown]
# (5) Write user defined PYTHON function to perform the following analysis: You need to find top 10 customers for each city in terms of their repayment amount by different products and by different time periods i.e. year or month. The user should be able to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the function should automatically take these inputs while identifying the top 10 customers.

# %%
cust_repay.head()
# Out:
#    SL No: Customer      Month     Amount  No   Age       City Product  \
# 0     NaN       A1 2004-01-12  495414.75   1  76.0  BANGALORE    Gold
# 1     2.0       A1 2004-01-03  245899.02   1  76.0  BANGALORE    Gold
# 2     3.0       A1 2004-01-15  259490.06   1  76.0  BANGALORE    Gold
# 3     4.0       A1 2004-01-25  437555.12   1  76.0  BANGALORE    Gold
# 4     5.0       A1 2005-01-17  165972.88   1  76.0  BANGALORE    Gold
#
#       Limit Company        Segment    month  year
# 0  500000.0      C1  Self Employed  January  2004
# 1  500000.0      C1  Self Employed  January  2004
# 2  500000.0      C1  Self Employed  January  2004
# 3  500000.0      C1  Self Employed  January  2004
# 4  500000.0      C1  Self Employed  January  2005

# %% [markdown]
# (5) Write user defined PYTHON function to perform the following analysis: You need to find top 10 customers for each city in terms of their repayment amount by different products and by different time periods i.e. year or month. The user should be able to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the function should automatically take these inputs while identifying the top 10 customers.

# %%
    cust_repay.head(2)
# Out:
#    SL No: Customer      Month     Amount  No   Age       City Product  \
# 0     NaN       A1  12-Jan-04  495414.75   1  76.0  BANGALORE    Gold
# 1     2.0       A1   3-Jan-04  245899.02   1  76.0  BANGALORE    Gold
#
#       Limit Company        Segment
# 0  500000.0      C1  Self Employed
# 1  500000.0      C1  Self Employed

# %%
cust_repay["Month"]=pd.to_datetime(cust_repay["Month"])

# %%
cust_repay["month"]=cust_repay["Month"].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
cust_repay["year"]=cust_repay["Month"].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
def summary(product,timeperiod):
    print("Enter the product & timeperiod")
    if product.lower()=="gold" and timeperiod.lower()=="month":
        pivot=cust_repay.pivot_table(index=["Product","City","Customer"],columns="month",aggfunc="sum",values="Amount")
        result=pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif  product.lower()=="gold" and timeperiod.lower()=="year":
        pivot=cust_repay.pivot_table(index=["Product","City","Customer"],columns="year",aggfunc="sum",values="Amount")
        result=pivot.loc[('Gold'['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=="silver" and timeperiod.lower()=="month":
        pivot=cust_repay.pivot_table(index=["Product","City","Customer"],columns="month",aggfunc="sum",values="Amount")
        result=pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif  product.lower()=="silver" and timeperiod.lower()=="year":
        pivot=cust_repay.pivot_table(index=["Product","City","Customer"],columns="year",aggfunc="sum",values="Amount")
        result=pivot.loc[('Silver'['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]  
    elif product.lower()=="platinum" and timeperiod.lower()=="month":
        pivot=cust_repay.pivot_table(index=["Product","City","Customer"],columns="month",aggfunc="sum",values="Amount")
        result=pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif  product.lower()=="platinum" and timeperiod.lower()=="year":
        pivot=cust_repay.pivot_table(index=["Product","City","Customer"],columns="year",aggfunc="sum",values="Amount")
        result=pivot.loc[('Platinum'['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]  
    return result
# Out:
# <>:8: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:14: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:20: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:8: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:14: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:20: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\USER\AppData\Local\Temp\ipykernel_10864\2188799745.py:8: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   result=pivot.loc[('Gold'['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
# ...

# %%
summary('gold','month')
# Out:
# Enter the product & timeperiod
# month                             April     August   December    February  \
# Product City       Customer
# Gold    BANGALORE  A1         508949.16        NaN        NaN   781873.80
#                    A13        494392.40  873304.51        NaN  2049808.15
#                    A14        812582.20  198623.13  388821.96  1482923.34
#                    A30        425694.16        NaN        NaN  1321469.80
#                    A43        612541.80        NaN        NaN   763846.93
#                    A63              NaN        NaN        NaN         NaN
#                    A81              NaN        NaN        NaN         NaN
#                    A88              NaN        NaN        NaN         NaN
#                    A92        459105.69        NaN        NaN         NaN
#         COCHIN     A11        958466.08  332677.61        NaN  1069789.26
#                    A16        338710.86        NaN        NaN   331143.85
# ...
